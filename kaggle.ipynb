# %%
# !kaggle datasets list -s coffee
# Out:
# ref                                             title                                     size  lastUpdated                 downloadCount  voteCount  usabilityRating
# ----------------------------------------------  ----------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# ihelon/coffee-sales                             Coffee Sales                             43929  2025-03-25 10:20:05.300000          52617        521                1
# michals22/coffee-dataset                        Coffee dataset                           24496  2022-12-15 20:02:12.277000          20195        244                1
# jawad3664/coffee-shop                           coffee shop                              30439  2025-09-23 09:42:41.813000           2371         66                1
# ...

# %%
# !kaggle datasets download -d uom190346a/global-coffee-health-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/uom190346a/global-coffee-health-dataset
# License(s): CC0-1.0
# ...
#   0%|          | 0.00/184k [00:00<?, ?B/s]
# 100%|██████████| 184k/184k [00:01<00:00, 155kB/s]
# 100%|██████████| 184k/184k [00:01<00:00, 155kB/s]

# %%
import zipfile
import os

zip_path = "./global-coffee-health-dataset.zip"
extract_path = "./data"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
import pandas as pd

df = pd.read_csv("./global-coffee-health-dataset.zip/coffee_health_dataset/coffee_health_dataset.csv")

# %%
import zipfile

zip_path = "./coffee_clean.csv.zip"
extract_path = "csv./data"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
import zipfile
zip_path = "./coffee_list.csv.zip"
extract_path = "csv./data"
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
import zipfile
zip_path = "./coffee_clean.csv.zip"
extract_path = "csv./data"
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
# !kaggle datasets list -s roastery
# Out:
# ref                                                 title                                         size  lastUpdated                 downloadCount  voteCount  usabilityRating
# --------------------------------------------------  --------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# kalilurrahman/starbucks-stock-data-live-and-latest  Starbucks Stock Data - Live and Latest      275205  2025-11-24 22:29:00.590000           2470         67                1
# kanchana1990/starbucks-nyc-1000-reviews             Starbucks NYC: 1000+ Reviews ☕              162902  2024-01-30 17:25:20.367000            876         69                1

# %%
# !kaggle datasets download -d marklvl/coffee-roastery-data, kalilurrahman/starbucks-stock-data-live-and-latest
# Out:
# Dataset URL: https://www.kaggle.com/datasets/kalilurrahman/starbucks-stock-data-live-and-latest
# License(s): CC0-1.0
# ...
#   0%|          | 0.00/269k [00:00<?, ?B/s]
# 100%|██████████| 269k/269k [00:00<00:00, 705kB/s]
# 100%|██████████| 269k/269k [00:00<00:00, 502kB/s]

# %%
# !kaggle datasets download -d kanchana1990/starbucks-nyc-1000-reviews
# Out:
# Dataset URL: https://www.kaggle.com/datasets/kanchana1990/starbucks-nyc-1000-reviews
# License(s): ODC Attribution License (ODC-By)
# ...
#   0%|          | 0.00/159k [00:00<?, ?B/s]
# 100%|██████████| 159k/159k [00:00<00:00, 373kB/s]
# 100%|██████████| 159k/159k [00:00<00:00, 372kB/s]

# %%
import zipfile
zip_path = "./starbucks-nyc-1000-reviews.zip"
extract_path = "csv./data"
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
import zipfile
zip_path = "./starbucks-stock-data-live-and-latest.zip"
extract_path = "csv./data"
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
# !pip scipy install

# %%
import sys
import scipy

# Install/upgrade pip and install scipy into the current Python environment
# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install scipy

# Verify installation
try:
    print("scipy version:", scipy.__version__)
except Exception as e:
    print("Failed to import scipy:", e)
# Out:
# ...
# scipy version: 1.16.3
